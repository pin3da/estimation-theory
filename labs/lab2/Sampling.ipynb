# %%
import numpy as np
import scipy as sp
import scipy.stats as stats
from scipy.stats import gaussian_kde as gkde
from scipy.special import gamma
from bokeh.plotting import figure, show, output_notebook, gridplot
from bokeh.models import Span

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d8d5cc8c-8959-4482-913a-2f404cfcdc15">Loading BokehJS ...</span>
#     </div>

# %%
# Utility functions to work with the normal distribution in terms of mean and
# variance.
def normPDF(x,mu=0.0, sig2=1.0):
    return stats.norm.pdf(x,mu,np.sqrt(sig2))

def normRVS(samples=1, mu=0.0, sig2=1.0):
#     return stats.norm.rvs(mu, np.sqrt(sig2), size=samples)
    return np.random.normal(mu,np.sqrt(sig2),size=samples)

# Utility functions to work with the gamma distribution
def gammaPDF(x, alpha, beta):
    return stats.gamma.pdf(x, alpha, beta)

def gammaRVS(alpha, beta, samples=1):
#     return stats.gamma.rvs(alpha,scale=beta,size=samples)
    return np.random.gamma(alpha, beta, size=samples)

# Utility functions to work with the uniform distribution
def uniformPDF(x,lower=0.0, upper=1.0):
    return stats.uniform.pdf(x, lower, upper)

def uniformRVS(samples=1, lower=0.0, upper=1.0):
#     return stats.uniform.rvs(lower, upper, size=samples)
    return np.random.uniform(lower,upper, size=samples)

# %% [markdown]
# Let $X \sim 0.3\cdot\mathcal{N}(x \vert -2, 0.8) + 0.7\cdot\mathcal{N}(x \vert 2, 0.8)$

# %%
def p(x):
    G1 = normPDF(x, -2.0, 0.8)
    G2 = normPDF(x, 2.0, 0.8)
    return 0.3*G1 + 0.7*G2

# %% [markdown]
# Plot of the distribution

# %%
X = np.linspace(-5.0,5.0,100)
PX = [p(x) for x in X]
f = figure(title="Gaussian mixture", x_axis_label='x', y_axis_label='P(x)',
           plot_width=300, plot_height=200)
f.line(X, PX, line_width=2)
show(f)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d0f036a7-dfc2-4cf8-b28f-468b75092fdb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d0f036a7-dfc2-4cf8-b28f-468b75092fdb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d0f036a7-dfc2-4cf8-b28f-468b75092fdb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd0f036a7-dfc2-4cf8-b28f-468b75092fdb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5feceee1-0795-4243-9703-18a019d69240":{"roots":{"references":[{"attributes":{"plot":{"id":"6d0ccbfd-d07d-4e50-a21a-59d51cc472ee","subtype":"Figure","type":"Plot"}},"id":"f8605f6f-6a55-4627-a38b-48efb1d46c60","type":"PanTool"},{"attributes":{"axis_label":"x","formatter":{"id":"cd31ff10-22b0-49f6-aee6-82e801da2b7f","type":"BasicTickFormatter"},"plot":{"id":"6d0ccbfd-d07d-4e50-a21a-59d51cc472ee","subtype":"Figure","type":"Plot"},"ticker":{"id":"e87ddc98-6ce0-45df-8532-b25cb8e0a6f2","type":"BasicTicker"}},"id":"94be30dc-4a47-4ab0-bf70-9f9de1136d83","type":"LinearAxis"},{"attributes":{"plot":{"id":"6d0ccbfd-d07d-4e50-a21a-59d51cc472ee","subtype":"Figure","type":"Plot"}},"id":"d8c3b386-5389-4745-8230-1f77079edacd","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6d0ccbfd-d07d-4e50-a21a-59d51cc472ee","subtype":"Figure","type":"Plot"},"ticker":{"id":"60280819-0587-4cfd-81d0-3933cdb4b616","type":"BasicTicker"}},"id":"fb6834a8-0722-476b-b1e2-481834387210","type":"Grid"},{"attributes":{"overlay":{"id":"f451d404-b4a5-40bd-935f-3959a89b1407","type":"BoxAnnotation"},"plot":{"id":"6d0ccbfd-d07d-4e50-a21a-59d51cc472ee","subtype":"Figure","type":"Plot"}},"id":"38448be1-4404-4372-94a4-d406aa497661","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f8605f6f-6a55-4627-a38b-48efb1d46c60","type":"PanTool"},{"id":"d8c3b386-5389-4745-8230-1f77079edacd","type":"WheelZoomTool"},{"id":"38448be1-4404-4372-94a4-d406aa497661","type":"BoxZoomTool"},{"id":"7e688d81-0a0e-4e74-85da-b45278035fa1","type":"SaveTool"},{"id":"88366f18-8d1d-45d5-bb1d-0fb2b026a137","type":"ResetTool"},{"id":"b4ac1793-fd8e-4d95-918d-0a57f7ab7c9b","type":"HelpTool"}]},"id":"7c6e022c-a383-45a0-84ec-80035097eff0","type":"Toolbar"},{"attributes":{},"id":"33a79ca4-dbd4-4e33-85f1-35a21c8b531d","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-5.0,-4.898989898989899,-4.797979797979798,-4.696969696969697,-4.595959595959596,-4.494949494949495,-4.393939393939394,-4.292929292929293,-4.191919191919192,-4.090909090909091,-3.9898989898989896,-3.888888888888889,-3.787878787878788,-3.686868686868687,-3.5858585858585856,-3.484848484848485,-3.383838383838384,-3.282828282828283,-3.1818181818181817,-3.080808080808081,-2.9797979797979797,-2.878787878787879,-2.7777777777777777,-2.676767676767677,-2.5757575757575757,-2.474747474747475,-2.3737373737373737,-2.272727272727273,-2.1717171717171717,-2.070707070707071,-1.9696969696969697,-1.868686868686869,-1.7676767676767677,-1.6666666666666665,-1.5656565656565657,-1.4646464646464645,-1.3636363636363638,-1.2626262626262625,-1.1616161616161618,-1.0606060606060606,-0.9595959595959593,-0.858585858585859,-0.7575757575757578,-0.6565656565656566,-0.5555555555555554,-0.45454545454545503,-0.3535353535353538,-0.2525252525252526,-0.15151515151515138,-0.050505050505050164,0.050505050505050164,0.15151515151515138,0.2525252525252526,0.3535353535353538,0.45454545454545414,0.5555555555555554,0.6565656565656566,0.7575757575757578,0.8585858585858581,0.9595959595959593,1.0606060606060606,1.1616161616161618,1.262626262626262,1.3636363636363633,1.4646464646464645,1.5656565656565657,1.666666666666667,1.7676767676767673,1.8686868686868685,1.9696969696969697,2.070707070707071,2.1717171717171713,2.2727272727272725,2.3737373737373737,2.474747474747475,2.5757575757575752,2.6767676767676765,2.7777777777777777,2.878787878787879,2.9797979797979792,3.0808080808080813,3.1818181818181817,3.282828282828282,3.383838383838384,3.4848484848484844,3.5858585858585865,3.686868686868687,3.787878787878787,3.8888888888888893,3.9898989898989896,4.09090909090909,4.191919191919192,4.292929292929292,4.3939393939393945,4.494949494949495,4.595959595959595,4.696969696969697,4.797979797979798,4.8989898989899,5.0],"y":[0.0004825917200701305,0.000700351235790375,0.0010034899492491621,0.0014196171900161495,0.00198285321962038,0.0027344562476413884,0.00372 ...

# %% [markdown]
# Draw samples from the distribution

# %%
def draw():
    pi = uniformRVS()
    mean = -2.0 if pi <= 0.3 else 2.0
    return np.random.normal(mean, 0.8)

# %% [markdown]
# Parzen estimator

# %%
def parzen(N,h,x):
    ans = 0.0
    den = 1.0 / np.sqrt(2.0 * np.pi * (h**2))
    for n in range(N):
        xn = draw()
        num = np.exp(- ((x - xn)**2.0) / (2.0 * h**2))
        ans += num / den
    return ans / N

# %%
Ns = [100, 1000]
hs = [0.2, 0.3, 0.4, 0.5]
x = np.linspace(-5.0,5.0,1000)
px = [p(i) for i in x]
plots = list()

for N in Ns:
    for h in hs:
        ttl = "Parzen n: " + str(N) + ", h: " + str(h)
        f = figure(title=ttl, x_axis_label='x', y_axis_label='ph(x)')
        phx = [parzen(N,h,i) for i in x]
        f.line(x, phx, legend="Parzen estimated", color="darkgreen")
        f.line(x, px, line_width=2, color="firebrick", legend="Real dist.")
        f.legend.location = "top_left"
        plots.append(f)

grid = gridplot(plots, ncols=2, plot_width=350, plot_height=250)
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9c97a152-ec17-42ca-8920-a8631b30f6f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9c97a152-ec17-42ca-8920-a8631b30f6f3").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9c97a152-ec17-42ca-8920-a8631b30f6f3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9c97a152-ec17-42ca-8920-a8631b30f6f3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"69f26fa3-96c9-4062-88b3-5bc87f8989e0":{"roots":{"references":[{"attributes":{"callback":null},"id":"4cf20976-2d11-4172-bfbf-78bca38d23d0","type":"DataRange1d"},{"attributes":{"plot":{"id":"599fd084-df7d-476f-890d-f4034c7ee85d","subtype":"Figure","type":"Plot"}},"id":"3d0ebba1-b637-45b0-b9c9-72f2ea6de29a","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"599fd084-df7d-476f-890d-f4034c7ee85d","subtype":"Figure","type":"Plot"}},"id":"0e059413-5e4c-46c3-808c-5a3713e786db","type":"SaveTool"},{"attributes":{"plot":{"id":"599fd084-df7d-476f-890d-f4034c7ee85d","subtype":"Figure","type":"Plot"}},"id":"17c0b948-1965-4301-bb34-e90475bee4ce","type":"PanTool"},{"attributes":{"overlay":{"id":"acdb85fb-7cc5-4157-b312-1ffb2a808af1","type":"BoxAnnotation"},"plot":{"id":"50fd28c3-9bf1-48dc-ac46-9793a3796bb1","subtype":"Figure","type":"Plot"}},"id":"b66e5a12-0997-4fdd-b02b-61cacae36993","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"bc61a738-570a-4420-9d23-f09d85385dba","subtype":"Figure","type":"Plot"},"ticker":{"id":"9e042ea7-bdda-4c3d-8c4b-2d5b7a3387a5","type":"BasicTicker"}},"id":"e2e7e223-f09f-4e5c-a210-ede4aeabde8e","type":"Grid"},{"attributes":{"plot":{"id":"e91b2fcb-209f-4652-a865-874b3561beb7","subtype":"Figure","type":"Plot"}},"id":"e8d6568f-3362-4232-a58c-426bcb25da01","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f954cd23-2520-40b3-bb34-5f82853af60d","type":"Line"},{"attributes":{"below":[{"id":"811dfcfb-8a96-41c9-8d99-bcad77ed4c39","type":"LinearAxis"}],"left":[{"id":"e4394191-4521-4adc-a413-6ad8189d22d5","type":"LinearAxis"}],"plot_height":250,"plot_width":350,"renderers":[{"id":"811dfcfb-8a96-41c9-8d99-bcad77ed4c39","type":"LinearAxis"},{"id":"82c66a27-215e-4ba1-8b19-c1c092d381a2","type":"Grid"},{"id":"e4394191-4521-4adc-a413-6ad8189d22d5","type":"LinearAxis"},{"id":"d1d597d2-3006-48c2-8526-222391a38c6a","type":"Grid"},{"id":"bc9aaca4-b565-40f0-8992-a712aeb97f9d","type":"BoxAnnotation"},{"id":"d1628af6-531c-42d7-9f21-c7116c6a2fd9","type":"Legend"},{"id":"52fb4111-4177-41b3-8f30-e8f053e2440a","type":"GlyphRenderer"},{"id":"85571c71-ca16-4b49-b777-957fdd355184","type":"GlyphRenderer"}],"title":{"id":"fc997ad7-45cd-4406-91ef-f0a255a82bb1","type":"Title"},"tool_events":{"id":"dc0868c8-1530-4704-bd9b-40766f3652e8","type":"ToolEvents"},"toolbar":{"id":"2db21586-4bac-466a-97e5-aacb01b65602","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"ff863b8c-f5c4-46fb-b2af-1701cb8d8702","type":"DataRange1d"},"y_range":{"id":"94f7ed7a-e59c-468c-967d-d9c2c296b285","type":"DataRange1d"}},"id":"e91b2fcb-209f-4652-a865-874b3561beb7","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7f88ece1-8fcd-4922-8fa7-a47d3201768e","type":"BasicTicker"},{"attributes":{},"id":"0c1984eb-fbf1-4111-b0f3-ff0a38834429","type":"BasicTickFormatter"},{"attributes":{"legends":[["Parzen estimated",[{"id":"52fb4111-4177-41b3-8f30-e8f053e2440a","type":"GlyphRenderer"}]],["Real dist.",[{"id":"85571c71-ca16-4b49-b777-957fdd355184","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"e91b2fcb-209f-4652-a865-874b3561beb7","subtype":"Figure","type":"Plot"}},"id":"d1628af6-531c-42d7-9f21-c7116c6a2fd9","type":"Legend"},{"attributes":{"callback":null},"id":"ff863b8c-f5c4-46fb-b2af-1701cb8d8702","type":"DataRange1d"},{"attributes":{"plot":{"id":"599fd084-df7d-476f-890d-f4034c7ee85d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e8e459b-0915-4351-a118-5843be5477c4","type":"BasicTicker"}},"id":"efd5c5ab-2276-4adc-a049-31a8ae15af8b","type":"Grid"},{"attributes":{"plot":null,"text":"Parzen n: 1000, h: 0.4"},"id":"12a95b46-565b-4cd5-a5de-5668c55cb462","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6ba7084-368b-44c5-a11d-254d1b4ef920","type":"Line"},{"attributes":{"data_source":{"id":"5a35374b-491a-42bc-aa5 ...

# %% [markdown]
# Using a Gaussian kernel density estimator from scipy. The higher the number of samples, the better kde fits the real distribution.

# %%
Ns = [10, 100, 1000, 10000]
plots = list()
for n in Ns:
    samples = [draw() for i in range(n)]
    kernel = gkde(samples)
    ttl = "Gaussian kernel estimator for " + str(n) + " samples"
    f = figure(title=ttl, x_axis_label='x', y_axis_label='p(x)')
    f.line(x, kernel(x), legend="Gaussian kernel est.",
           color="darkgreen", line_width=2)
    f.line(x, px, line_width=2, color="firebrick", legend="Real dist.")
    f.legend.location = "top_left"
    plots.append(f)

grid = gridplot(plots, ncols=2, plot_width=350, plot_height=400)
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e555ebf5-e471-4edb-913d-f65ed590604e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e555ebf5-e471-4edb-913d-f65ed590604e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e555ebf5-e471-4edb-913d-f65ed590604e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e555ebf5-e471-4edb-913d-f65ed590604e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9b4a7cc3-dba8-4a6d-9f70-a72f83d96f8f":{"roots":{"references":[{"attributes":{"data_source":{"id":"e66c4c64-fa5e-45b0-a74d-b12810a41860","type":"ColumnDataSource"},"glyph":{"id":"90485076-fc27-4673-9646-69d38d96b851","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f5e74c72-42ef-456f-a2ad-9f7128e55ec5","type":"Line"},"selection_glyph":null},"id":"0504adef-b606-4271-aa69-5f85d788e738","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Gaussian kernel estimator for 10 samples"},"id":"cdf79057-b8b0-4e79-bf21-9258292d0765","type":"Title"},{"attributes":{"axis_label":"p(x)","formatter":{"id":"773fee91-24d4-4f52-9419-8dd8bce0c7c8","type":"BasicTickFormatter"},"plot":{"id":"087e3606-4606-42a6-a46b-a5dfac703c68","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c1d61ec-d807-4b61-b49b-4cd2cc80234f","type":"BasicTicker"}},"id":"a3241a79-3669-47e1-82cb-c6a9fdfd3ee9","type":"LinearAxis"},{"attributes":{"below":[{"id":"ddfa3854-0e62-4125-9f1a-10fbe11d840c","type":"LinearAxis"}],"left":[{"id":"5f941366-7beb-45ad-bd5a-7aec4d883899","type":"LinearAxis"}],"plot_height":400,"plot_width":350,"renderers":[{"id":"ddfa3854-0e62-4125-9f1a-10fbe11d840c","type":"LinearAxis"},{"id":"602bbf33-e164-4504-a17b-c42cc1a794dc","type":"Grid"},{"id":"5f941366-7beb-45ad-bd5a-7aec4d883899","type":"LinearAxis"},{"id":"57ae06b8-5852-44fb-97a8-bb0512997d97","type":"Grid"},{"id":"0be3ac96-97d5-44dc-acb9-3883c924f953","type":"BoxAnnotation"},{"id":"7aada5b8-ba88-4ed5-bf20-de111f7ce409","type":"Legend"},{"id":"f9bc1d12-f943-4864-af26-b00288b45ba1","type":"GlyphRenderer"},{"id":"11b597c1-c2f6-4918-8c50-24755d02ccc3","type":"GlyphRenderer"}],"title":{"id":"cdf79057-b8b0-4e79-bf21-9258292d0765","type":"Title"},"tool_events":{"id":"8e5b6af6-3aea-47f8-adba-7f041a435ba5","type":"ToolEvents"},"toolbar":{"id":"08f0be44-a65d-4228-8935-52215c0b3b57","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"cf191fde-4c18-4b4f-a60e-5754004072e5","type":"DataRange1d"},"y_range":{"id":"756fb78a-de67-4391-8df6-4798bb4ef5e2","type":"DataRange1d"}},"id":"27517851-657b-4c2e-aa6f-067c22209109","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-5.0,-4.98998998998999,-4.97997997997998,-4.96996996996997,-4.95995995995996,-4.94994994994995,-4.93993993993994,-4.92992992992993,-4.91991991991992,-4.90990990990991,-4.8998998998999,-4.88988988988989,-4.87987987987988,-4.86986986986987,-4.85985985985986,-4.84984984984985,-4.83983983983984,-4.82982982982983,-4.81981981981982,-4.80980980980981,-4.7997997997998,-4.78978978978979,-4.77977977977978,-4.76976976976977,-4.75975975975976,-4.74974974974975,-4.73973973973974,-4.72972972972973,-4.71971971971972,-4.70970970970971,-4.6996996996997,-4.68968968968969,-4.67967967967968,-4.66966966966967,-4.65965965965966,-4.64964964964965,-4.63963963963964,-4.62962962962963,-4.61961961961962,-4.60960960960961,-4.5995995995996,-4.58958958958959,-4.57957957957958,-4.56956956956957,-4.55955955955956,-4.54954954954955,-4.53953953953954,-4.52952952952953,-4.51951951951952,-4.50950950950951,-4.4994994994995,-4.48948948948949,-4.47947947947948,-4.46946946946947,-4.45945945945946,-4.44944944944945,-4.43943943943944,-4.42942942942943,-4.41941941941942,-4.40940940940941,-4.3993993993994,-4.38938938938939,-4.37937937937938,-4.36936936936937,-4.35935935935936,-4.34934934934935,-4.33933933933934,-4.32932932932933,-4.31931931931932,-4.3093093093093096,-4.2992992992992995,-4.2892892892892895,-4.2792792792792795,-4.2692692692692695,-4.2592592592592595,-4.2492492492492495,-4.2392392392392395,-4.2292292292292295,-4.2192192192192195,-4.2092092092092095,-4.1991991991991995,-4.1891891891891895,-4.1791791791791795,-4.1691691691691695,-4.1591591591591595,-4.1491491491491495,-4.1391391391391394,-4.129129129129129,-4.119119119119119,-4.109109109109109,-4.099099099099099,-4.089089089089089,-4.079079079079079,-4.069069069069069,-4.059059059059059,-4.049049049049049,-4.039039039039039,-4. ...

# %% [markdown]
# # Sampling from Gaussian distribution

# %% [markdown]
# ## 1. Unknown mean ($\mu$), known variance ($\sigma^2$)

# %%
mu = 3.0
sig2 = 0.5

# %% [markdown]
# Find the mean $\mu$ of $p(x) \sim \mathcal{N}(x \vert \mu, \sigma^2)$. $\mu$ (unknown) and $\sigma^2$ which is known. The **real** distribution is presented below.

# %%
def p(x):
    return normPDF(x, mu, sig2)

x = np.linspace(-3.0,5.0,1000)
px = [p(i) for i in x]
f = figure(title="Real distribution", x_axis_label='x', y_axis_label='p(x)',
           plot_width=300, plot_height=300)
f.line(x, px, line_width=2, color="firebrick", legend="Real dist.")
f.legend.location = "top_left"
show(f)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="67bccf40-fb0f-44ce-a088-081d2128b998"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#67bccf40-fb0f-44ce-a088-081d2128b998").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("67bccf40-fb0f-44ce-a088-081d2128b998");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '67bccf40-fb0f-44ce-a088-081d2128b998' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"356e411d-16f5-41d6-a430-cacb7be5d44b":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"},"ticker":{"id":"4035a8b0-15f3-4a74-8f68-0a3d81ccc5b5","type":"BasicTicker"}},"id":"a33e6529-d643-4854-9c12-5920eb0e443f","type":"Grid"},{"attributes":{},"id":"eb9a2f89-04aa-4373-a160-045bc973dd36","type":"BasicTicker"},{"attributes":{},"id":"aad1bc4e-54a3-416c-bfeb-5c20697b7946","type":"BasicTickFormatter"},{"attributes":{},"id":"4035a8b0-15f3-4a74-8f68-0a3d81ccc5b5","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ac1c7502-3f8a-41a7-b567-6df42afd3f19","type":"DataRange1d"},{"attributes":{"plot":{"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"}},"id":"e7686656-d7a1-44bd-87a5-fa58a7494377","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"97f62d26-fdf9-4abf-be14-8544b3a4bb11","type":"ColumnDataSource"},"glyph":{"id":"afb3e11b-5f30-4506-a73f-1333abec202e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d96b1ced-a613-4944-8255-672770a0d048","type":"Line"},"selection_glyph":null},"id":"176963f7-4705-4985-9666-8816574afaf4","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b8ef8c98-dabd-4dac-868c-6ca99e1a8328","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"Real distribution"},"id":"721e2da3-30df-4c51-8332-3e7b299b1637","type":"Title"},{"attributes":{"plot":{"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"}},"id":"c423cc0c-bf00-4f41-a02a-b9e39cab5234","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d96b1ced-a613-4944-8255-672770a0d048","type":"Line"},{"attributes":{"below":[{"id":"ab9512c9-4347-4ce4-954e-6dce2cbaf460","type":"LinearAxis"}],"left":[{"id":"12010cf4-e7c1-48af-a2c9-fd2083015462","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"ab9512c9-4347-4ce4-954e-6dce2cbaf460","type":"LinearAxis"},{"id":"023eda34-bb3e-4a2b-bcf1-ca020907c2ea","type":"Grid"},{"id":"12010cf4-e7c1-48af-a2c9-fd2083015462","type":"LinearAxis"},{"id":"a33e6529-d643-4854-9c12-5920eb0e443f","type":"Grid"},{"id":"b8ef8c98-dabd-4dac-868c-6ca99e1a8328","type":"BoxAnnotation"},{"id":"bce43ad4-1a95-4208-9b7d-d2e6a6ac320e","type":"Legend"},{"id":"176963f7-4705-4985-9666-8816574afaf4","type":"GlyphRenderer"}],"title":{"id":"721e2da3-30df-4c51-8332-3e7b299b1637","type":"Title"},"tool_events":{"id":"31e3d2af-9fa5-4280-ab39-30af860452df","type":"ToolEvents"},"toolbar":{"id":"6bd8d0c0-f551-4b18-a9ce-cd5514a6a1f2","type":"Toolbar"},"x_range":{"id":"ac1c7502-3f8a-41a7-b567-6df42afd3f19","type":"DataRange1d"},"y_range":{"id":"eef8676f-b3da-4294-8db4-d577bafdd8e2","type":"DataRange1d"}},"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"afb3e11b-5f30-4506-a73f-1333abec202e","type":"Line"},{"attributes":{"plot":{"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb9a2f89-04aa-4373-a160-045bc973dd36","type":"BasicTicker"}},"id":"023eda34-bb3e-4a2b-bcf1-ca020907c2ea","type":"Grid"},{"attributes":{"axis_label":"p(x)","formatter":{"id":"aad1bc4e-54a3-416c-bfeb-5c20697b7946","type":"BasicTickFormatter"},"plot":{"id":"9e239a77-3057-4a01-948e-b110d4c0e4af","subtype":"Figure","type":"Plot"},"ticker":{"id":"4035a8b0-15f3-4a74-8f68-0a3d81ccc5b5","type":"BasicTicker"}},"id":"12010cf4-e7c1-48af-a2c9-fd2083015462","type":"LinearAxis"},{"attributes":{"plot":{"id":" ...

# %%
N = 30
D = normRVS(N, mu, sig2)

# %% [markdown]
# We assume there is a set $D= \{x_n\}^{N}_{n=1}$ of $N$ samples drawn from the distribution above.

# %% [markdown]
# ### 1.1. Rejection sampling
#
# The goal is to find $\mu$.
#
# \begin{align*}
# p(\mu\vert D, \sigma^2) = \frac{p(D \vert \mu, \sigma^2)p(\mu)}{p(D)}
# \end{align*}
#
# Assuming $Z_p = p(D)$ is the multiplicative constant we obtain:
#
# \begin{align*}
# p(\mu \vert D, \sigma^2) &= \frac{1}{Z_p}\widetilde{p}(\mu \vert D, \sigma^2) \\
# \widetilde{p}(\mu \vert D, \sigma^2) &= p(D\vert \mu, \sigma^2)p(\mu)
# \end{align*}

# %% [markdown]
# - Likelihood:
#
# \begin{align*}
# p(D \vert \mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} exp \left\{\frac{\sum_{n=1}^N (x_n - \mu)^2}{2\sigma^2} \right\}
# \end{align*}

# %%
def likelihood_(mu):
    a = 1.0 / ((2.0 * np.pi * sig2) ** (N / 2.0))
    b = -np.sum((D - mu) ** 2) / (2.0 * sig2)
    return a * np.exp(b)
likelihood = np.vectorize(likelihood_)

# %% [markdown]
# - Prior:
#
# \begin{align*}
# q(\mu) = p(\mu) = \frac{1}{\sqrt{2\pi\sigma^2_0}} exp\left\{-\frac{(\mu - \mu_0)^2}{2\sigma^2_0}\right\}
# \end{align*}

# %%
mu0 = 2.0

# %% [markdown]
# - Posterior:
#
# The posterior distribution using exact Bayesian inference. This will only be used to compare the accuracy.

# %%
def posterior(mu0, s20, s2, X, n):
    muml = np.sum(X[0 : n]) / n
    mun = (s2 * mu0 / (n * s20 + s2)) +  n * s20 * muml / (n * s20 + s2)
    sign = 1.0 / ((1.0 / s20) +  (n / s2))
    return mun, sign

muk, sigk = posterior(mu0, sig2, sig2, D, N)

def pz(z):
    return stats.norm.pdf(z, muk, np.sqrt(sigk))

# %% [markdown]
# Initial value for the hyper-parameter $\mu_0$. $\sigma_0^2 = \sigma^2$ beacuse the variance of the ditribution is known.

# %%
def q(z):
    return normPDF(z,mu0,sig2)

def draw_q(samples):
    return normRVS(samples, mu0, sig2)

# %% [markdown]
# - $k$:
#
# \begin{align*}
# k &= p(D \vert \mu_{ML}, \sigma^2) \\
# \mu_{ML} &= \frac{1}{N}\sum_{n=1}^N x_n
# \end{align*}
#
# - Acceptance:
# Let $u \sim \mathcal{U}(0,1)$, we accept a sample from $q(\mu)$ iff
#
# \begin{align*}
# u \leq \frac{p(D \vert \mu, \sigma^2)}{p(D \vert \mu_{ML}, \sigma^2)}
# \end{align*}
#
# The proportion is derived from:
#
# \begin{align*}
# \frac{\widetilde{p}(\mu)}{kq(\mu)} = \frac{p(D \vert \mu, \sigma^2)p(\mu)}{p(D \vert \mu_{ML}, \sigma^2)p(\mu)} = \frac{p(D \vert \mu, \sigma^2)}{p(D \vert \mu_{ML}, \sigma^2)}
# \end{align*}
# Hence, computing $k$ directly is not needed.

# %%
def rejectionSampling(N):
    # Draw N samples from the proposal distribution
    samples = draw_q(N)
    # Compute the maximum lakelihood for the mean
    muML = np.mean(D)
    # Compute the proportion between the probability of the data given the
    # mean and the probability of the data given muML.
    proportion = likelihood(samples) / likelihood(muML)
    u = uniformRVS(N)
    # Accept the samples for which a random sample is less than or equal to 
    # the proportion.
    return samples[u <= proportion]

# %% [markdown]
# ### Results
#
# We perform 4 experiments to evaluate the rejection sampling approach to find $\mu$ for the distribution. Each experiment is defined by the number of samples that rejection sampling will take to approximate $\mu$. The 4 sample sizes are $\{10, 100, 500, 1000\}$.
#
# There is a plot for each experiment in which at least 2 samples were accepted. The dark green dotted line signals the initial value for the hyperparameter $\mu_0$. The dotted red line signals the real value of the mean for the underlying distribution. Finally, the purple dotted line is the result of the posterior using exact Bayesian inference.

# %%
Ns = [10, 100, 500, 1000]
x = np.linspace(0, 5, 300)

plots = list()
for n in Ns:
    samples = rejectionSampling(n)
    if len(samples) > 1:
        kernel = gkde(samples)
        ttl = "Samples=" + str(n) + " accepted=" + str(len(samples) / float(n)) 
        f = figure(title=ttl, x_axis_label='x', y_axis_label='p(x)')
        f.line(x, kernel(x), legend="Estimation",
               color="darkgreen", line_width=2)
        f.line(x, pz(x), legend='Posterior', color='purple', alpha=0.5, line_width=2, line_dash='dashed')
        realMean = Span(location=mu, dimension='height',
                        line_color='firebrick', line_dash='dashed',
                        line_width=2)
        priorMean = Span(location=mu0, dimension='height',
                        line_color='DarkOliveGreen', line_dash='dashed',
                        line_width=2)
        f.add_layout(realMean)
        f.add_layout(priorMean)
        f.legend.location = "top_left"
        plots.append(f)

grid = gridplot(plots, ncols=2, plot_width=350, plot_height=350)
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c765e433-485e-4ccb-8e4b-cac41ff9a673"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c765e433-485e-4ccb-8e4b-cac41ff9a673").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c765e433-485e-4ccb-8e4b-cac41ff9a673");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c765e433-485e-4ccb-8e4b-cac41ff9a673' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c990057f-ed6f-486f-8dba-0e750f1ceea0":{"roots":{"references":[{"attributes":{"dimension":"height","line_color":{"value":"DarkOliveGreen"},"line_dash":[6],"line_width":{"value":2},"location":2.0,"plot":{"id":"79bafaf0-a96f-4313-bc49-2140848edf29","subtype":"Figure","type":"Plot"}},"id":"a3ce104d-7577-4e2f-b1c4-e987a9f3c7ba","type":"Span"},{"attributes":{"plot":{"id":"b7943172-9356-422e-b408-6b46787962e9","subtype":"Figure","type":"Plot"}},"id":"2b579d39-0736-4231-86b6-418d004dc55a","type":"SaveTool"},{"attributes":{"children":[{"id":"6d406e01-c98b-4f9e-a316-ed07673b04de","subtype":"Figure","type":"Plot"},{"id":"79bafaf0-a96f-4313-bc49-2140848edf29","subtype":"Figure","type":"Plot"}]},"id":"2e1b9efe-4d61-45af-bb8b-5ce6857767aa","type":"Row"},{"attributes":{"axis_label":"x","formatter":{"id":"6870c7f0-9c53-4c23-a32d-3bc6e6d6920e","type":"BasicTickFormatter"},"plot":{"id":"6d406e01-c98b-4f9e-a316-ed07673b04de","subtype":"Figure","type":"Plot"},"ticker":{"id":"3da2f8e9-5322-4b8b-803e-f6d16927561a","type":"BasicTicker"}},"id":"f935a0bc-5ec2-4965-979b-5b0024322840","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"ea49d1b7-347b-4aec-bc24-72f9510e9b4f","subtype":"Figure","type":"Plot"},"ticker":{"id":"7112b62f-0a68-459d-9ba6-6c705af6ed8c","type":"BasicTicker"}},"id":"9b9d190f-8211-4905-893e-2c398439dc46","type":"Grid"},{"attributes":{"plot":{"id":"6d406e01-c98b-4f9e-a316-ed07673b04de","subtype":"Figure","type":"Plot"}},"id":"cee3c03f-f679-4aed-b936-3fc4ef27afb1","type":"HelpTool"},{"attributes":{"data_source":{"id":"39f5b83d-c176-43fb-9170-e0b705e31941","type":"ColumnDataSource"},"glyph":{"id":"a72aadbc-6e03-4573-9dcc-452bbe7b14cd","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"95c9e197-1634-43f4-a6b1-f8b36f7108d4","type":"Line"},"selection_glyph":null},"id":"0d4d70f6-8e4b-4b54-9ecb-f29c1e45ef82","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b7943172-9356-422e-b408-6b46787962e9","subtype":"Figure","type":"Plot"}},"id":"86ca4643-0162-4103-8a9b-c33698d9cc27","type":"HelpTool"},{"attributes":{},"id":"142ddf86-3622-47f0-b0c3-74ec5bff9aaa","type":"BasicTickFormatter"},{"attributes":{"legends":[["Estimation",[{"id":"0089b680-81e4-47dc-a531-5ba9482ecfe9","type":"GlyphRenderer"}]],["Posterior",[{"id":"81a6dd82-2cc2-4518-8fe3-73f0f70bed31","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"ea49d1b7-347b-4aec-bc24-72f9510e9b4f","subtype":"Figure","type":"Plot"}},"id":"5eb26905-51bc-4b7b-9e16-d0f3a87a7e3f","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.016722408026755852,0.033444816053511704,0.05016722408026755,0.06688963210702341,0.08361204013377926,0.1003344481605351,0.11705685618729096,0.13377926421404682,0.15050167224080266,0.16722408026755853,0.18394648829431437,0.2006688963210702,0.21739130434782608,0.23411371237458192,0.2508361204013378,0.26755852842809363,0.2842809364548495,0.3010033444816053,0.3177257525083612,0.33444816053511706,0.3511705685618729,0.36789297658862874,0.3846153846153846,0.4013377926421404,0.4180602006688963,0.43478260869565216,0.451505016722408,0.46822742474916385,0.4849498327759197,0.5016722408026756,0.5183946488294314,0.5351170568561873,0.5518394648829431,0.568561872909699,0.5852842809364548,0.6020066889632106,0.6187290969899665,0.6354515050167224,0.6521739130434783,0.6688963210702341,0.68561872909699,0.7023411371237458,0.7190635451505016,0.7357859531772575,0.7525083612040133,0.7692307692307692,0.785953177257525,0.8026755852842808,0.8193979933110368,0.8361204013377926,0.8528428093645485,0.8695652173913043,0.8862876254180602,0.903010033444816,0.9197324414715718,0.9364548494983277,0.9531772575250835,0.9698996655518394,0.9866220735785953,1.0033444816053512,1.020066889632107,1.0367892976588629,1.0535117056856187,1.0702341137123745,1.0869565217391304,1.1036789297658862,1.120401337792642,1.137123745819398,1.1538461538461537,1.1705685618729096,1.1872909698996654,1.2040133779264213,1.220735785953177,1.237 ...

# %% [markdown]
# ### Cocnlusions
#
# Rejection sampling performs well approximating $\mu$. However, when few samples are taken from the experiment of $10$ samples all of them are rejected and there is no output for that particular experiment. In the other three experiments we can see from the plots that $\mu$ is precisely approximated. Interestingly, the real value of $\mu$ is approximated with a relatively low percentage of accepted samples.

# %% [markdown]
# ### 1.2. Sampling importance resampling (SIR)

# %%
def q(z):
    return stats.norm.pdf(z, mu0, sig2) #normPDF(z, mu0, sig2)

def draw_q(n):
    return np.random.normal(mu0, sig2, size=n)# return normRVS(n, mu0, sig2)

# %% [markdown]
# $\widetilde{p}(\mu \vert D, \sigma^2) = p(D\vert \mu, \sigma^2)p(\mu)$

# %%
def pt(z):
    return likelihood(z) * q(z)

# %%
def computeWeights(n):
    s = draw_q(n)
    w = pt(s) / q(s)
    den = np.sum(w)
    w = w / den
    assert (abs(np.sum(w) - 1) < 1e-10)
    return s, w

# %%
def SIR(n, r):
    s,w = computeWeights(n)
    accu = np.copy(w)
    for i in range(1, n):
        accu[i] += accu[i - 1]

    samples = []
    for i in range(r):
        index = np.searchsorted(accu, np.random.uniform())
        samples.append(s[index])
    return samples

# %% [markdown]
# ### Results
#
# This time we tried SIR on three settings. Each setting is described by the pair $(n,r)$ where $n$ is the number of original samples and $r$ is the number of re-samples. The experiments considered $\{(100, 20), (1000, 100), (100000, 10000) \}$. For every experiment we present a plot of the estimated mean (in green), the posterior from Bayesian exact inference (in purple) and the initial and real means in dotted green and dotted red respectively.

# %%
Nexp = [100, 1000, 100000]
Nrem = [20, 100, 10000]
x = np.linspace(0, 5, 300)

plots = list()
for k in range(len(Nexp)):
    n = Nexp[k]
    r = Nrem[k]
    samples = SIR(n,r)
    
    kernel = stats.gaussian_kde(samples)
        
    ttl = "SI=" + str(n) + " R=" + str(len(samples))
    f = figure(title=ttl, x_axis_label='x', y_axis_label='p(x)')
    f.line(x, kernel(x), legend="Est. mean",
           color="darkgreen", line_width=2)
        
#     f.line(x, q(x), legend='prior', line_width=2)
    f.line(x, pz(x), legend='Posterior', color='purple', line_width=2,
           line_dash='dashed', alpha=0.5)
        
    realMean = Span(location=mu, dimension='height',
                    line_color='firebrick', line_dash='dashed',
                    line_width=2)
    priorMean = Span(location=mu0, dimension='height',
                     line_color='DarkOliveGreen', line_dash='dashed',
                     line_width=2)
    f.add_layout(realMean)
    f.add_layout(priorMean)
    f.legend.location = "top_left"
    plots.append(f)
    
grid = gridplot(plots, ncols=2, plot_width=350, plot_height=350)
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5384810d-3ebe-4715-b006-cf4d8f24abc5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5384810d-3ebe-4715-b006-cf4d8f24abc5").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5384810d-3ebe-4715-b006-cf4d8f24abc5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5384810d-3ebe-4715-b006-cf4d8f24abc5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d1c35af1-f1f7-49e1-8168-32135e3b0c62":{"roots":{"references":[{"attributes":{},"id":"75f367df-88eb-4b72-87d5-684321eca525","type":"BasicTicker"},{"attributes":{"data_source":{"id":"d4751301-db22-4f31-bb8f-da47985f4c41","type":"ColumnDataSource"},"glyph":{"id":"a5c32989-6300-4d52-8ffd-cf9bbc9e1781","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"48519454-970b-4a7a-ba1c-93a1599d8215","type":"Line"},"selection_glyph":null},"id":"c735ea7e-becc-43a4-bd7b-ed7c8aed9159","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"purple"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"351a8fda-a68a-42a0-8db8-2885c8d1212f","type":"Line"},{"attributes":{"dimension":"height","line_color":{"value":"DarkOliveGreen"},"line_dash":[6],"line_width":{"value":2},"location":2.0,"plot":{"id":"b450b854-1bdb-45d3-8118-321c7cbb7760","subtype":"Figure","type":"Plot"}},"id":"580a03c6-eac8-4124-8b0f-9a246b620650","type":"Span"},{"attributes":{"legends":[["Est. mean",[{"id":"000890ba-0954-4b3a-93b1-5601e427bcf8","type":"GlyphRenderer"}]],["Posterior",[{"id":"71670d65-955c-4db7-afef-fa0c793da3b5","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"2cdf25cd-a9bf-4d4d-b29a-d41d829014a7","subtype":"Figure","type":"Plot"}},"id":"8ab1de20-65a6-4ba2-945e-ac5bada6ba66","type":"Legend"},{"attributes":{"callback":null},"id":"648f319c-535a-45e4-8077-8a97e311d1c3","type":"DataRange1d"},{"attributes":{"plot":{"id":"b450b854-1bdb-45d3-8118-321c7cbb7760","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c8298ff-5968-4989-ae0d-68440ee39392","type":"BasicTicker"}},"id":"afd6736c-67c0-41a0-9a3d-4f9ae9dd7243","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb0ef13a-6ce0-4f07-af96-76a9d076f064","type":"Line"},{"attributes":{"overlay":{"id":"bb1a0e35-2a42-47f3-bcf9-fb867bedf1c4","type":"BoxAnnotation"},"plot":{"id":"2cdf25cd-a9bf-4d4d-b29a-d41d829014a7","subtype":"Figure","type":"Plot"}},"id":"708c65a9-5718-4948-b081-af48b81eca44","type":"BoxZoomTool"},{"attributes":{"axis_label":"p(x)","formatter":{"id":"ea9ff54b-87b9-4860-93bd-fc0d39a15e92","type":"BasicTickFormatter"},"plot":{"id":"b450b854-1bdb-45d3-8118-321c7cbb7760","subtype":"Figure","type":"Plot"},"ticker":{"id":"d3cee779-14f7-4ed8-9263-b64c3fc06a05","type":"BasicTicker"}},"id":"69aeb0c7-be19-4f2b-b6a0-7db1c1fdac47","type":"LinearAxis"},{"attributes":{"dimension":"height","line_color":{"value":"DarkOliveGreen"},"line_dash":[6],"line_width":{"value":2},"location":2.0,"plot":{"id":"2cdf25cd-a9bf-4d4d-b29a-d41d829014a7","subtype":"Figure","type":"Plot"}},"id":"1200f5db-8c3e-4330-9f55-db4a9befdb98","type":"Span"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6f126e5-f67b-4c28-bb97-1ac0faf8c58a","type":"Line"},{"attributes":{"line_color":{"value":"darkgreen"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"26f6044a-8f51-4cf2-88b1-c0cb55ee5177","type":"Line"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"c0691680-4a03-4d4a-97d4-57c67644d425","type":"PanTool"},{"id":"0d6beaef-e7d4-42e5-9fe0-030cee2ce139","type":"WheelZoomTool"},{"id":"b0b02125-d298-45f0-a80c-6142546a5f57","type":"BoxZoomTool"},{"id":"cbd0e675-7972-4a35-bf27-5a0a620a2173","type":"SaveTool"},{"id":"35e2a963-4c02-4a98-8364-a7781a93ad12","type":"ResetTool"},{"id":"0724223b-72e3-409f-a7a1-41913755767b","type":"HelpTool"},{"id":"ff315c9a-3199-418b-a91c-498955abbcae","type":"PanTool"},{"id":"7fc6243e-c648-4123-989b-1adb3ed76620","type":"WheelZoomTool"},{"id":"9834c6b5-98ba-4774-abe1-06db7e853fdb","type":"BoxZoomTool"},{"id":"6a43dd6a-660a-4661-ba0d-ab3af7c345da","type":"SaveTool"},{"id":"a06d5e89-e1de-46ba-8ff3-b5859c9c7343","type":"ResetTool"},{"id":"4811b3aa-c6ba- ...

# %% [markdown]
# ### Conclusions
#
# The first clear conclusion is that both SIR and exact Bayesian estimation are very close in the approximated value of $\mu$.This approximation is also close to the real value. Another conclusion in that using SIR allows to try a higher number of initial samples when compared to the rejection sampling approach.
