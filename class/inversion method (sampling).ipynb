# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import multivariate_normal
from scipy.stats import norm
from numpy import random as rd

# %%
la = 0.5

def f_inv(y):
    return - np.log(1.0 - y) / la

def pdf(z):
    if (z >= 0):
        return la * np.exp(-la * z)
    else:
        return 0

def draw():
    yz = rd.uniform()
    z = f_inv(yz)
    return z


def esti(N, h, x):
    ans = 0
    den = np.sqrt(2.0 * np.pi * (h ** 2.0))
    for i in range(N):
        xn = draw()
        num = np.exp(- ((x - xn) ** 2.0) / (2.0 * (h ** 2))) 
        ans += num / den
    return ans / N

x = np.linspace(0, 5, 300)

Nexp = [10000]
Hexp = [0.5, 0.01, 0.04]

for n in Nexp:
    for h in Hexp:
        plt.plot(x, [pdf(i) for i in x])
        y = []
        for i in x:
            y.append(esti(n, h, i))
        plt.plot(x, y)
        plt.title("Using n = %d, h = %f" % (n, h))
        plt.show()
